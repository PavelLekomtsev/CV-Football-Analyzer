# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# Requirement already satisfied: ultralytics in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (8.2.54)
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from ultralytics) (1.24.4)
# Requirement already satisfied: matplotlib>=3.3.0 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from ultralytics) (1.10.1)
# Requirement already satisfied: torch>=1.8.0 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from ultralytics) (2.3.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from ultralytics) (0.18.1)
# Requirement already satisfied: tqdm>=4.64.0 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from ultralytics) (6.0.0)
# Requirement already satisfied: py-cpuinfo in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from ultralytics) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from ultralytics) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (6.4.0)
# Requirement already satisfied: pytz>=2020.1 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.7.4)
# Requirement already satisfied: filelock in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.0)
# Requirement already satisfied: networkx in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (2021.4.0)
# Requirement already satisfied: colorama in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: zipp>=3.1.0 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.0->ultralytics) (3.19.2)
# Requirement already satisfied: intel-openmp==2021.* in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.8.0->ultralytics) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.8.0->ultralytics) (2021.13.0)
# Requirement already satisfied: six>=1.5 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: roboflow in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (1.1.34)
# Requirement already satisfied: certifi in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from roboflow) (2024.7.4)
# Requirement already satisfied: chardet==4.0.0 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from roboflow) (4.0.0)
# Requirement already satisfied: idna==3.7 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from roboflow) (3.7.5)
# Requirement already satisfied: numpy>=1.18.5 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from roboflow) (1.24.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from roboflow) (10.4.0)
# Requirement already satisfied: python-dateutil in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from roboflow) (2.2.2)
# Requirement already satisfied: tqdm>=4.41.0 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from roboflow) (4.66.4)
# Requirement already satisfied: PyYAML>=5.3.1 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: python-magic in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from roboflow) (0.4.27)
# Requirement already satisfied: colorama in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from matplotlib->roboflow) (1.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from matplotlib->roboflow) (4.53.1)
# Requirement already satisfied: packaging>=20.0 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from matplotlib->roboflow) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from matplotlib->roboflow) (3.1.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from matplotlib->roboflow) (6.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from requests->roboflow) (3.3.2)
# Requirement already satisfied: zipp>=3.1.0 in e:\work\computer_vision\projects\footballanalyzer\.venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->roboflow) (3.19.2)
# [notice] A new release of pip is available: 23.2.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="L36Y9LDBLXHi9Dvs9S1l")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
dataset.location
# Out:
# 'E:\\Work\\Computer_Vision\\Projects\\FootballAnalyzer\\training\\football-players-detection-1'

# %%
import shutil

shutil.move("football-players-detection-1/train",
            "football-players-detection-1/football-players-detection-1/train")

shutil.move("football-players-detection-1/test",
            "football-players-detection-1/football-players-detection-1/test")

shutil.move("football-players-detection-1/valid",
            "football-players-detection-1/football-players-detection-1/valid")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python38\lib\shutil.py:791, in move(src, dst, copy_function)
#     790 try:
# --> 791     os.rename(src, real_dst)
#     792 except OSError:
#
# FileNotFoundError: [WinError 2] Не удается найти указанный файл: 'football-players-detection-1/train' -> 'football-players-detection-1/football-players-detection-1/train\\train'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 import shutil
# ----> 3 shutil.move("football-players-detection-1/train",
#       4             "football-players-detection-1/football-players-detection-1/train")
#       6 shutil.move("football-players-detection-1/test",
#       7             "football-players-detection-1/football-players-detection-1/test")
#       9 shutil.move("football-players-detection-1/valid",
#      10             "football-players-detection-1/football-players-detection-1/valid")
#
# File ~\AppData\Local\Programs\Python\Python38\lib\shutil.py:811, in move(src, dst, copy_function)
#     809         rmtree(src)
#     810     else:
# --> 811         copy_function(src, real_dst)
#     812         os.unlink(src)
#     813 return real_dst
#
# File ~\AppData\Local\Programs\Python\Python38\lib\shutil.py:435, in copy2(src, dst, follow_symlinks)
#     433 if os.path.isdir(dst):
#     434     dst = os.path.join(dst, os.path.basename(src))
# --> 435 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     436 copystat(src, dst, follow_symlinks=follow_symlinks)
#     437 return dst
#
# File ~\AppData\Local\Programs\Python\Python38\lib\shutil.py:264, in copyfile(src, dst, follow_symlinks)
#     262     os.symlink(os.readlink(src), dst)
#     263 else:
# --> 264     with open(src, 'rb') as fsrc, open(dst, 'wb') as fdst:
#     265         # macOS
#     266         if _HAS_FCOPYFILE:
#     267             try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'football-players-detection-1/train'

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov5l.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# PRO TIP рџ’Ў Replace 'model=yolov5l.pt' with new 'model=yolov5lu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov5lu.pt to 'yolov5lu.pt'...
# New https://pypi.org/project/ultralytics/8.2.64 available рџ�ѓ Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.54 рџљЂ Python-3.8.10 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# engine\trainer: task=detect, mode=train, model=yolov5l.pt, data=E:\Work\Computer_Vision\Projects\FootballAnalyzer\training\football-players-detection-1/data.yaml, epochs=100, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs\detect\train
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      7040  ultralytics.nn.modules.conv.Conv             [3, 64, 6, 2, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    156928  ultralytics.nn.modules.block.C3              [128, 128, 3]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   1118208  ultralytics.nn.modules.block.C3              [256, 256, 6]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  9   6433792  ultralytics.nn.modules.block.C3              [512, 512, 9]
#   7                  -1  1   4720640  ultralytics.nn.modules.conv.Conv             [512, 1024, 3, 2]
#   8                  -1  3   9971712  ultralytics.nn.modules.block.C3              [1024, 1024, 3]
#   9                  -1  1   2624512  ultralytics.nn.modules.block.SPPF            [1024, 1024, 5]
#  10                  -1  1    525312  ultralytics.nn.modules.conv.Conv             [1024, 512, 1, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  3   2757632  ultralytics.nn.modules.block.C3              [1024, 512, 3, False]
#  14                  -1  1    131584  ultralytics.nn.modules.conv.Conv             [512, 256, 1, 1]
#  15                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  16             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  3    690688  ultralytics.nn.modules.block.C3              [512, 256, 3, False]
#  18                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  19            [-1, 14]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  3   2495488  ultralytics.nn.modules.block.C3              [512, 512, 3, False]
#  21                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  22            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  23                  -1  3   9971712  ultralytics.nn.modules.block.C3              [1024, 1024, 3, False]
#  24        [17, 20, 23]  1   7060444  ultralytics.nn.modules.head.Detect           [4, [256, 512, 1024]]
# YOLOv5l summary: 416 layers, 53166428 parameters, 53166412 gradients, 135.3 GFLOPs
#
# Transferred 685/691 items from pretrained weights
# Freezing layer 'model.24.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
#   0%|          | 0.00
#  91%|#########1| 93.1M/102M [00:14<00:00, 9.56MB/s]
#  92%|#########2| 94.1M/102M [00:14<00:00, 9.76MB/s]
#  93%|#########3| 95.1M/102M [00:14<00:00, 9.78MB/s]
#  94%|#########4| 96.2M/102M [00:14<00:00, 10.1MB/s]
#  95%|#########5| 97.2M/102M [00:14<00:00, 10.1MB/s]
#  96%|#########6| 98.4M/102M [00:14<00:00, 10.4MB/s]
#  97%|#########7| 99.4M/102M [00:14<00:00, 10.4MB/s]
#  99%|#########8| 100M/102M [00:14<00:00, 10.7MB/s]
# 100%|#########9| 102M/102M [00:14<00:00, 10.8MB/s]
# 100%|##########| 102M/102M [00:14<00:00, 7.18MB/s]
#
#   0%|          | 0.00/6.25M [00:00<?, ?B/s]
#   2%|2         | 128k/6.25M [00:00<00:07, 896kB/s]
#   6%|6         | 384k/6.25M [00:00<00:04, 1.41MB/s]
#  16%|#6        | 1.00M/6.25M [00:00<00:01, 3.24MB/s]
#  36%|###6      | 2.25M/6.25M [00:00<00:00, 6.29MB/s]
#  74%|#######4  | 4.62M/6.25M [00:00<00:00, 12.0MB/s]
#  98%|#########8| 6.12M/6.25M [00:00<00:00, 13.0MB/s]
# 100%|##########| 6.25M/6.25M [00:00<00:00, 9.02MB/s]
# Traceback (most recent call last):
#   File "C:\Users\Pavel\AppData\Local\Programs\Python\Python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Pavel\AppData\Local\Programs\Python\Python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "E:\Work\Computer_Vision\Projects\FootballAnalyzer\.venv\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "E:\Work\Computer_Vision\Projects\FootballAnalyzer\.venv\lib\site-packages\ultralytics\cfg\__init__.py", line 708, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#   File "E:\Work\Computer_Vision\Projects\FootballAnalyzer\.venv\lib\site-packages\ultralytics\engine\model.py", line 650, in train
#     self.trainer.train()
#   File "E:\Work\Computer_Vision\Projects\FootballAnalyzer\.venv\lib\site-packages\ultralytics\engine\trainer.py", line 204, in train
#     self._do_train(world_size)
#   File "E:\Work\Computer_Vision\Projects\FootballAnalyzer\.venv\lib\site-packages\ultralytics\engine\trainer.py", line 323, in _do_train
#     self._setup_train(world_size)
#   File "E:\Work\Computer_Vision\Projects\FootballAnalyzer\.venv\lib\site-packages\ultralytics\engine\trainer.py", line 262, in _setup_train
#     self.amp = torch.tensor(check_amp(self.model), device=self.device)
#   File "E:\Work\Computer_Vision\Projects\FootballAnalyzer\.venv\lib\site-packages\ultralytics\utils\checks.py", line 663, in check_amp
#     assert amp_allclose(YOLO("yolov8n.pt"), im)
#   File "E:\Work\Computer_Vision\Projects\FootballAnalyzer\.venv\lib\site-packages\ultralytics\utils\checks.py", line 650, in amp_allclose
#     a = m(im, device=device, verbose=False)[0].boxes.data  # FP32 inference
#   File "E:\Work\Computer_Vision\Projects\FootballAnalyzer\.venv\lib\site-packages\ultralytics\engine\model.py", line 174, in __call__
#     return self.predict(source, stream, **kwargs)
#   File "E:\Work\Computer_Vision\Projects\FootballAnalyzer\.venv\lib\site-packages\ultralytics\engine\model.py", line 442, in predict
#     return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#   File "E:\Work\Computer_Vision\Projects\FootballAnalyzer\.venv\lib\site-packages\ultralytics\engine\predictor.py", line 168, in __call__
#     return list(self.stream_inference(source, model, *args, **kwargs))  # merge list of Result into one
#   File "E:\Work\Computer_Vision\Projects\FootballAnalyzer\.venv\lib\site-packages\torch\utils\_contextlib.py", line 35, in generator_context
#     response = gen.send(None)
#   File "E:\Work\Computer_Vision\Projects\FootballAnalyzer\.venv\lib\site-packages\ultralytics\engine\predictor.py", line 261, in stream_inference
#     self.results = self.postprocess(preds, im, im0s)
#   File "E:\Work\Computer_Vision\Projects\FootballAnalyzer\.venv\lib\site-packages\ultralytics\models\yolo\detect\predict.py", line 25, in postprocess
#     preds = ops.non_max_suppression(
#   File "E:\Work\Computer_Vision\Projects\FootballAnalyzer\.venv\lib\site-packages\ultralytics\utils\ops.py", line 291, in non_max_suppression
#     i = torchvision.ops.nms(boxes, scores, iou_thres)  # NMS
#   File "E:\Work\Computer_Vision\Projects\FootballAnalyzer\.venv\lib\site-packages\torchvision\ops\boxes.py", line 41, in nms
#     return torch.ops.torchvision.nms(boxes, scores, iou_threshold)
#   File "E:\Work\Computer_Vision\Projects\FootballAnalyzer\.venv\lib\site-packages\torch\_ops.py", line 854, in __call__
#     return self_._op(*args, **(kwargs or {}))
# NotImplementedError: Could not run 'torchvision::nms' with arguments from the 'CUDA' backend. This could be because the operator doesn't exist for this backend, or was omitted during the selective/custom build process (if using custom build). If you are a Facebook employee using PyTorch on mobile, please visit https://fburl.com/ptmfixes for possible resolutions. 'torchvision::nms' is only available for these backends: [CPU, Meta, QuantizedCPU, BackendSelect, Python, FuncTorchDynamicLayerBackMode, Functionalize, Named, Conjugate, Negative, ZeroTensor, ADInplaceOrView, AutogradOther, AutogradCPU, AutogradCUDA, AutogradXLA, AutogradMPS, AutogradXPU, AutogradHPU, AutogradLazy, AutogradMeta, Tracer, AutocastCPU, AutocastCUDA, FuncTorchBatched, BatchedNestedTensor, FuncTorchVmapMode, Batched, VmapMode, FuncTorchGradWrapper, PythonTLSSnapshot, FuncTorchDynamicLayerFrontMode, PreDispatch, PythonDispatcher].
#
# CPU: registered at C:\actions-runner\_work\vision\vision\pytorch\vision\torchvision\csrc\ops\cpu\nms_kernel.cpp:112 [kernel]
# Meta: registered at /dev/null:467 [kernel]
# QuantizedCPU: registered at C:\actions-runner\_work\vision\vision\pytorch\vision\torchvision\csrc\ops\quantized\cpu\qnms_kernel.cpp:124 [kernel]
# BackendSelect: fallthrough registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\core\BackendSelectFallbackKernel.cpp:3 [backend fallback]
# Python: registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\core\PythonFallbackKernel.cpp:154 [backend fallback]
# FuncTorchDynamicLayerBackMode: registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\functorch\DynamicLayer.cpp:497 [backend fallback]
# Functionalize: registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\FunctionalizeFallbackKernel.cpp:324 [backend fallback]
# Named: registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\core\NamedRegistrations.cpp:7 [backend fallback]
# Conjugate: registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\ConjugateFallback.cpp:17 [backend fallback]
# Negative: registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\NegateFallback.cpp:18 [backend fallback]
# ZeroTensor: registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\ZeroTensorFallback.cpp:86 [backend fallback]
# ADInplaceOrView: fallthrough registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\core\VariableFallbackKernel.cpp:86 [backend fallback]
# AutogradOther: registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\core\VariableFallbackKernel.cpp:53 [backend fallback]
# AutogradCPU: registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\core\VariableFallbackKernel.cpp:57 [backend fallback]
# AutogradCUDA: registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\core\VariableFallbackKernel.cpp:65 [backend fallback]
# AutogradXLA: registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\core\VariableFallbackKernel.cpp:69 [backend fallback]
# AutogradMPS: registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\core\VariableFallbackKernel.cpp:77 [backend fallback]
# AutogradXPU: registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\core\VariableFallbackKernel.cpp:61 [backend fallback]
# AutogradHPU: registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\core\VariableFallbackKernel.cpp:90 [backend fallback]
# AutogradLazy: registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\core\VariableFallbackKernel.cpp:73 [backend fallback]
# AutogradMeta: registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\core\VariableFallbackKernel.cpp:81 [backend fallback]
# Tracer: registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\autograd\TraceTypeManual.cpp:297 [backend fallback]
# AutocastCPU: registered at C:\actions-runner\_work\vision\vision\pytorch\vision\torchvision\csrc\ops\autocast\nms_kernel.cpp:34 [kernel]
# AutocastCUDA: registered at C:\actions-runner\_work\vision\vision\pytorch\vision\torchvision\csrc\ops\autocast\nms_kernel.cpp:27 [kernel]
# FuncTorchBatched: registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\functorch\LegacyBatchingRegistrations.cpp:731 [backend fallback]
# BatchedNestedTensor: registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\functorch\LegacyBatchingRegistrations.cpp:758 [backend fallback]
# FuncTorchVmapMode: fallthrough registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\functorch\VmapModeRegistrations.cpp:27 [backend fallback]
# Batched: registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\LegacyBatchingRegistrations.cpp:1075 [backend fallback]
# VmapMode: fallthrough registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\VmapModeRegistrations.cpp:33 [backend fallback]
# FuncTorchGradWrapper: registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\functorch\TensorWrapper.cpp:202 [backend fallback]
# PythonTLSSnapshot: registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\core\PythonFallbackKernel.cpp:162 [backend fallback]
# FuncTorchDynamicLayerFrontMode: registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\functorch\DynamicLayer.cpp:493 [backend fallback]
# PreDispatch: registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\core\PythonFallbackKernel.cpp:166 [backend fallback]
# PythonDispatcher: registered at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\core\PythonFallbackKernel.cpp:158 [backend fallback]
